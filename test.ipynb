# %%
from sklearn.model_selection import train_test_split
import pandas as pd


df = pd.read_csv("csv_files/dataset.csv")
label_column = 'Landcover'


X = df.drop(label_column, axis=1)
y = df[label_column]

test_size  = 0.3
X_train, X_unseen, y_train, y_unseen = train_test_split(
    X, y, test_size=test_size, stratify=y, random_state=1
)

# %% [markdown]
# X_train (70), y_train = gagamitin mo to for training. Meaning pati yung kfold, dito galing
#
# Given na 100 rows and 10 folds
# X_train (63) X_val (7) - iteration 1
# X_train (63) X_val (7) - iteration 2
# ...
# X_train (63) X_val (7) - iteration 10
#
#
#
#
# mg = pd concat (X_yrain, y_train)
# yung mg>saksak mo sa pycaret: meaning, yung X_train lang talaga ang ginamit mo for training.
# 10 folds
# Mean:0.7 - accuracy ng training
#
# accuracy ni X_test: malapit dapat to sa training.
#
#
#
# pag sobrang layo ng test score compared sa training > overfit
# pag malayo sa 1 (accuracy) > underfit
#
#
# to solve underfitting > add more features. however, this will cause more overfitting

# %% [markdown]
# 1. Explain data split
# 2. Explain
