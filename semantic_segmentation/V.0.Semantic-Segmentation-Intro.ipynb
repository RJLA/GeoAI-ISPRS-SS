# %% [markdown]
# #### Image Segmentation
#
# - Let us know `WHAT` is in the image.
#
# #### Object Detection
#
# - Let us know `WHAT` and `WHERE` is the object in the image (bounding box).
#
#
# <img src="figures/objectdetection.jpg" alt="Alt text" width="500" height="300">
#
# #### Image Segmentation
#
# - Prediction for classes of each pixel rather than for a complete image
# - Applicable for satellite image
#
#
# <img src="figures/semantic.jpg" alt="Alt text" width="500" height="300">

# %% [markdown]
# #### Use a color image and (HxWx3) and return the segmentation mask (HxWx1)
#
# <img src="figures/segment_array.jpg" alt="Alt text" width="700" height="300">
#
#
# #### Return a binary segmentation mask (HxWx1) for each class
# <img src="figures/segment_array_channels.jpg" alt="Alt text" width="700" height="400">
